# %% [markdown]
# # Libraries

# %%
import pandas as pd
from pathlib import Path
from modules.utils import load_data

# %% [markdown]
# # Dataset

# %%
load_data()
# Out:
# Retrieving folder contents
# Retrieving folder 1s9X4xtl5XeR9Fpmtw7WVTHfKozkUylM4 test
# Processing file 1JqogVVdWwg4SgziG4A1DWHNf6rBDi61p 1.jpg
# Processing file 19SUz8SrxVkucINElja1n7XFctsu1JAFR 10.jpg
# Processing file 1Xcm2lihrCoEIAbcYq67wt_66n3JA2jlP 100.jpg
# Processing file 1Hr96obI5XqbYfqfq58Qg-OiTasez4Vd1 1000.jpg
# Processing file 1Bp9i8bi1VmccizmEQpoRF7pzyhdwDFYV 1001.jpg
# Processing file 1jkhG-UeD7BF1Ik3FVH4jqbQrkufUEzka 1002.jpg
# Processing file 1oMpa9BYiZmsGQmvmnG3chxHVau_eEIlA 1003.jpg
# Processing file 1oxRLr4UjuCDgdl7y4y7P8RsU3Zh2o3on 1004.jpg
# Processing file 1ctuHfxvKLIPh1Je_R41PTP4rk-vL0bEF 1005.jpg
# Processing file 1iy2lPo7rXPvjrgNOa1ZfVR-9MU4r_WfS 1006.jpg
# Processing file 1UjSemV0XwFO8IktfOj7V-1kRi8tgfFvs 1007.jpg
# Processing file 1Er2s0yz05jiUF5NTUCG4sCDtFVJSoeVZ 1008.jpg
# Processing file 19nJe_yJo429JEyYB24sQ9AleJxIQzaSn 1009.jpg
# Processing file 1dAfwqLxpjztDFQaEA8VNIrVRsXO5WuSH 101.jpg
# Processing file 19Ikx1w5UZ9BVDovYrT4vLyF48209TknF 1010.jpg
# ...

# %% [markdown]
# # EDA
