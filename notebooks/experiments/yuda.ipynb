# %% [markdown]
# # Yuda — Heavy Models + Advanced
# RTX 4050 6GB | batch_size=32 | accumulation_steps=1

# %%
import sys
sys.path.insert(0, "../..")

from modules.utils.config import *
from modules.utils.seed import set_seed
from modules.data.dataset import get_dataloaders
from modules.models.factory import TrashClassifier
from modules.training.train import fit

set_seed(SEED)
print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %%
MODELS = [
    "resnet50",
    "convnext_tiny",
    "vit_small_patch16_224",
    "efficientnet_b3",
    "resnext50_32x4d",
]

BATCH_SIZE = 32
ACCUMULATION_STEPS = 1
NUM_WORKERS = 4
EPOCHS_HEAD = 10
EPOCHS_FINETUNE = 20
LR_HEAD = 1e-3
LR_FINETUNE = 1e-4
PATIENCE = 10

# %%
train_loader, val_loader, val_ds = get_dataloaders(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
)
print(f"Train: {len(train_loader.dataset)} | Val: {len(val_loader.dataset)}")
# Out:
# Train: 21221 | Val: 5306

# %%
results = []
for model_name in MODELS:
    model = TrashClassifier(model_name, num_classes=NUM_CLASSES).to(DEVICE)
    res = fit(
        model, train_loader, val_loader,
        name=f"yuda_{model_name}",
        encoder_name=model_name,
        accumulation_steps=ACCUMULATION_STEPS,
        epochs_head=EPOCHS_HEAD,
        epochs_finetune=EPOCHS_FINETUNE,
        lr_head=LR_HEAD,
        lr_finetune=LR_FINETUNE,
        patience=PATIENCE,
        class_weights=val_ds.class_weights,
        device=DEVICE,
    )
    results.append(res)
    print(f">>> {model_name}: val_f1_macro = {res['best_val_f1']:.4f}")
# Out:
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:86: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# === yuda_resnet50: Phase 1 — Head Only ===
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                        /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E01: train_loss=0.4146  val_f1=0.8804  best=0.8804
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E02: train_loss=0.3386  val_f1=0.9126  best=0.9126
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E03: train_loss=0.3076  val_f1=0.9090  best=0.9126
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E04: train_loss=0.2960  val_f1=0.9217  best=0.9217
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E05: train_loss=0.2727  val_f1=0.9290  best=0.9290
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E06: train_loss=0.2623  val_f1=0.9197  best=0.9290
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E07: train_loss=0.2606  val_f1=0.9250  best=0.9290
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E08: train_loss=0.2301  val_f1=0.9271  best=0.9290
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E09: train_loss=0.2343  val_f1=0.9279  best=0.9290
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:125: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#   E10: train_loss=0.2325  val_f1=0.9312  best=0.9312
#
# === yuda_resnet50: Phase 2 — Fine-tune All ===
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E11: train_loss=0.2201  val_f1=0.9387  best=0.9387
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E12: train_loss=0.1638  val_f1=0.9508  best=0.9508
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E13: train_loss=0.1269  val_f1=0.9536  best=0.9536
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E14: train_loss=0.1025  val_f1=0.9600  best=0.9600
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E15: train_loss=0.0946  val_f1=0.9602  best=0.9602
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E16: train_loss=0.0775  val_f1=0.9633  best=0.9633
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E17: train_loss=0.0693  val_f1=0.9590  best=0.9633
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E18: train_loss=0.0585  val_f1=0.9683  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E19: train_loss=0.0487  val_f1=0.9651  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E20: train_loss=0.0472  val_f1=0.9671  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E21: train_loss=0.0372  val_f1=0.9656  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E22: train_loss=0.0380  val_f1=0.9674  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E23: train_loss=0.0307  val_f1=0.9672  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E24: train_loss=0.0274  val_f1=0.9648  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E25: train_loss=0.0284  val_f1=0.9672  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E26: train_loss=0.0247  val_f1=0.9682  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E27: train_loss=0.0231  val_f1=0.9673  best=0.9683
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E28: train_loss=0.0210  val_f1=0.9698  best=0.9698
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E29: train_loss=0.0214  val_f1=0.9663  best=0.9698
# yuda_resnet50 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E30: train_loss=0.0225  val_f1=0.9672  best=0.9698
# yuda_resnet50 val:   0%|          | 0/166 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# >>> resnet50: val_f1_macro = 0.9698
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:86: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# === yuda_convnext_tiny: Phase 1 — Head Only ===
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E01: train_loss=0.1852  val_f1=0.9609  best=0.9609
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E02: train_loss=0.1263  val_f1=0.9625  best=0.9625
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E03: train_loss=0.1036  val_f1=0.9713  best=0.9713
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E04: train_loss=0.0902  val_f1=0.9678  best=0.9713
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E05: train_loss=0.0710  val_f1=0.9735  best=0.9735
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E06: train_loss=0.0639  val_f1=0.9726  best=0.9735
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E07: train_loss=0.0521  val_f1=0.9727  best=0.9735
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E08: train_loss=0.0423  val_f1=0.9726  best=0.9735
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E09: train_loss=0.0368  val_f1=0.9730  best=0.9735
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:125: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#   E10: train_loss=0.0376  val_f1=0.9742  best=0.9742
#
# === yuda_convnext_tiny: Phase 2 — Fine-tune All ===
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E11: train_loss=0.2312  val_f1=0.9460  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E12: train_loss=0.1572  val_f1=0.9524  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E13: train_loss=0.1047  val_f1=0.9531  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E14: train_loss=0.1061  val_f1=0.9428  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E15: train_loss=0.0715  val_f1=0.9526  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E16: train_loss=0.0738  val_f1=0.9388  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E17: train_loss=0.0588  val_f1=0.9589  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E18: train_loss=0.0572  val_f1=0.9557  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E19: train_loss=0.0395  val_f1=0.9551  best=0.9742
# yuda_convnext_tiny train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E20: train_loss=0.0242  val_f1=0.9575  best=0.9742
#   Early stopping at epoch 20
# yuda_convnext_tiny val:   0%|          | 0/166 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# >>> convnext_tiny: val_f1_macro = 0.9742
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:86: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# === yuda_vit_small_patch16_224: Phase 1 — Head Only ===
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E01: train_loss=0.3187  val_f1=0.9281  best=0.9281
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E02: train_loss=0.2359  val_f1=0.9391  best=0.9391
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E03: train_loss=0.2067  val_f1=0.9374  best=0.9391
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E04: train_loss=0.1897  val_f1=0.9425  best=0.9425
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E05: train_loss=0.1743  val_f1=0.9497  best=0.9497
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E06: train_loss=0.1611  val_f1=0.9495  best=0.9497
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E07: train_loss=0.1481  val_f1=0.9534  best=0.9534
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E08: train_loss=0.1329  val_f1=0.9539  best=0.9539
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E09: train_loss=0.1308  val_f1=0.9551  best=0.9551
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:125: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#   E10: train_loss=0.1304  val_f1=0.9559  best=0.9559
#
# === yuda_vit_small_patch16_224: Phase 2 — Fine-tune All ===
# yuda_vit_small_patch16_224 train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_vit_small_patch16_224 val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E11: train_loss=0.2081  val_f1=0.9547  best=0.9559
# ...
#   with torch.no_grad(), autocast():
# /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:125: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#   E10: train_loss=0.2399  val_f1=0.9233  best=0.9252
#
# === yuda_resnext50_32x4d: Phase 2 — Fine-tune All ===
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E11: train_loss=0.2154  val_f1=0.9532  best=0.9532
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                         /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E12: train_loss=0.1361  val_f1=0.9514  best=0.9532
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E13: train_loss=0.0995  val_f1=0.9556  best=0.9556
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E14: train_loss=0.0870  val_f1=0.9597  best=0.9597
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                          /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E15: train_loss=0.0698  val_f1=0.9659  best=0.9659
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E16: train_loss=0.0550  val_f1=0.9583  best=0.9659
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E17: train_loss=0.0542  val_f1=0.9566  best=0.9659
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E18: train_loss=0.0366  val_f1=0.9629  best=0.9659
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E19: train_loss=0.0303  val_f1=0.9582  best=0.9659
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E20: train_loss=0.0218  val_f1=0.9666  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E21: train_loss=0.0226  val_f1=0.9620  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E22: train_loss=0.0193  val_f1=0.9636  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E23: train_loss=0.0159  val_f1=0.9646  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E24: train_loss=0.0144  val_f1=0.9649  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E25: train_loss=0.0108  val_f1=0.9657  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E26: train_loss=0.0112  val_f1=0.9635  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E27: train_loss=0.0097  val_f1=0.9642  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E28: train_loss=0.0089  val_f1=0.9627  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E29: train_loss=0.0071  val_f1=0.9641  best=0.9666
# yuda_resnext50_32x4d train:   0%|          | 0/664 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:51: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]                           /home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
#   E30: train_loss=0.0055  val_f1=0.9635  best=0.9666
#   Early stopping at epoch 30
# yuda_resnext50_32x4d val:   0%|          | 0/166 [00:00<?, ?it/s]/home/prayudahlah/projects/external/big-data-big-trouble/notebooks/experiments/../../modules/training/train.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# >>> resnext50_32x4d: val_f1_macro = 0.9666

# %%
import pandas as pd
summary = pd.DataFrame(results)
summary = summary.sort_values("best_val_f1", ascending=False)
summary.to_csv(RESULTS / "yuda_summary.csv", index=False)
summary[["name", "best_val_f1", "f1_per_class"]]
# Out:
#                          name  best_val_f1  \
# 1          yuda_convnext_tiny     0.974228
# 3        yuda_efficientnet_b3     0.970578
# 0               yuda_resnet50     0.969842
# 4        yuda_resnext50_32x4d     0.966590
# 2  yuda_vit_small_patch16_224     0.955948
#
#                                         f1_per_class
# 1  [0.9450990223113562, 0.9638854296388543, 0.963...
# 3  [0.9543650793650794, 0.9849435382685069, 0.964...
# 0  [0.9541375872382851, 0.980466288594833, 0.9670...
# 4  [0.9527127924340468, 0.9715729627289956, 0.966...
# 2  [0.9398587776966155, 0.9612015018773467, 0.955...

# %% [markdown]
# ## Advanced: Focal Loss + Mixup on best model

# %%
import torch.nn as nn

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = nn.functional.cross_entropy(inputs, targets, weight=self.alpha, reduction="none")
        pt = (-ce_loss).exp()
        return (pt.clamp(min=1e-8).pow(self.gamma) * ce_loss).mean()


best_model_name = MODELS[0]  # ganti setelah lihat hasil baseline

experiments = [
    ("focal_gamma2", FocalLoss(alpha=val_ds.class_weights.to(DEVICE))),
    ("ce_weighted", None),
]

for loss_name, loss_fn in experiments:
    model = TrashClassifier(best_model_name, num_classes=NUM_CLASSES).to(DEVICE)
    res = fit(
        model, train_loader, val_loader,
        name=f"yuda_adv_{best_model_name}_{loss_name}",
        encoder_name=best_model_name,
        accumulation_steps=ACCUMULATION_STEPS,
        epochs_head=EPOCHS_HEAD,
        epochs_finetune=EPOCHS_FINETUNE,
        lr_head=LR_HEAD,
        lr_finetune=LR_FINETUNE,
        patience=PATIENCE,
        criterion=loss_fn,
        device=DEVICE,
    )
    results.append(res)
